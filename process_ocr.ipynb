# %% [markdown]
# # Step 1: Set Name and PDF Path
#
# Name will be used as the name of the folder and file in `books_work` where the OCR results will be saved.
#
# The PDF path should be the path to the PDF file you want to process.
#
# I recommend you copy the file path from the file explorer.

# %%
from dotenv import load_dotenv

load_dotenv("./.env")

from ocr.ocr_pdf import ocr_pdf

path = "c:/Users/natha/Zotero/storage/LR6YL5A9/Ribier - 1666 - Lettres Et Memoires D'Estat Des Roys, Princes, Amb.pdf"

name = "ribier_v1"

# %% [markdown]
# # Step 2: Run OCR and save results to Parquet

# %%
# ocr_pdf(pdf_path=path, name=name)

# %% [markdown]
# The `ocr.parquet` fill will now contain the OCR results for each page of the PDF in a structured format:
#
# - `page_index`: The index of the page in the PDF (starting from 0).
# - `markdown`: The OCR text for that page in Markdown format.
#
# It will be saved in the `books_work/{name}/data/` directory, where `{name}` is the name you specified in Step 1.

# %% [markdown]
# # Processing OCR Results
#
# Inside the `books_work/{name}/` directory, you can create a `{name}.ipynb` notebook where you can load the `ocr.parquet` file and further process the OCR results, such as extracting headers, images, or performing any additional analysis you need.

# %% [markdown]
# # Embedding the OCR results
#
# Open the `embed_ocr.ipynb` notebook. Set the path for the processed parquet file and run the notebook to generate embeddings for the OCR results. The embeddings will be added to the `books_work/{name}/data/{name}.parquet` file via polars.
